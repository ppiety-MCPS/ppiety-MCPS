# %% [markdown]
# <a href="https://colab.research.google.com/github/ppiety-MCPS/ppiety-MCPS/blob/main/Test_ipcanvas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ipycanvas import Canvas

canvas = Canvas(width=200, height=200)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-113061144.py in <cell line: 0>()
# ----> 1 from ipycanvas import Canvas
#       2
#       3 canvas = Canvas(width=200, height=200)
#       4
#
# ModuleNotFoundError: No module named 'ipycanvas'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
